# %%
# !unzip /content/fire_detection_deghani.zip

# %%
# !pip install -r/content/fire_detection_deghani/requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '/content/fire_detection_deghani/requirements.txt'

# %%
# !pip install -q kaggle
# !mkdir -p ~/.kaggle 
# !cp kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d dangvanthuc0209/firedataset
# Out:
# ...
# 100% 761M/761M [00:40<00:00, 20.8MB/s]
# 100% 761M/761M [00:40<00:00, 19.7MB/s]

# %%
# !unzip /content/firedataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: yolov5-fire-detection/datasets/fire/train/images/WEBFire577.jpg
#   inflating: yolov5-fire-detection/datasets/fire/train/images/WEBFire579.jpg
#   inflating: yolov5-fire-detection/datasets/fire/train/images/WEBFire580.jpg
#   inflating: yolov5-fire-detection/datasets/fire/train/images/WEBFire581.jpg
#   inflating: yolov5-fire-detection/datasets/fire/train/images/WEBFire591.jpg
#   inflating: yolov5-fire-detection/datasets/fire/train/images/WEBFire592.jpg
#   inflating: yolov5-fire-detection/datasets/fire/train/images/WEBFire593.jpg
#   inflating: yolov5-fire-detection/datasets/fire/train/images/WEBFire594.jpg
#   inflating: yolov5-fire-detection/datasets/fire/train/images/WEBFire595.jpg
#   inflating: yolov5-fire-detection/datasets/fire/train/images/WEBFire596.jpg
#   inflating: yolov5-fire-detection/datasets/fire/train/images/WEBFire597.jpg
# ...

# %%
# !pip install timm
# !pip install addict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 30.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 88.3 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python /content/fire_detection_deghani/scripts/train.py  --batch 42 --epochs 30 --data /content/yolov5-fire-detection/data.yaml --cfg /content/fire_detection_deghani/configs/model_yolo.yaml  --hyp /content/fire_detection_deghani/configs/hyp.scratch-high.yaml
# Out:
# 2023-05-19 08:16:41.089095: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-19 08:16:42.213789: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# ...

# %%
pip install torchsummary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install efficientnet_pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for efficientnet_pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16427 sha256=f52199fa279db012057e52c02597da800ed13a3088e562ffdaa900a559d92111
#   Stored in directory: /root/.cache/pip/wheels/03/3f/e9/911b1bc46869644912bda90a56bcf7b960f20b5187feea3baf
# Successfully built efficientnet_pytorch
# ...

# %%
pip install yolov5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.3/953.3 kB 54.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 24.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.4/589.4 kB 60.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 12.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 15.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 30.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 128.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 12.7 MB/s eta 0:00:00
# ...

# %%
from torchvision import transforms
from torchvision import datasets
dataset = datasets.ImageFolder(root='//content//Human-Pose-2')

# %%
from PIL import Image
import torch 
import torchvision
import torch.nn as nn
from torchsummary import summary
import torchvision.models as models
# تنظیمات پردازش تصویر
batch_size = 32
img_height = 224
img_width = 224
from yolov5.models.yolo import Model

# تابع برای پردازش تصویر

from torchvision import transforms

from torchvision import datasets

batch_size = 16
img_height = 640
img_width = 640
transform = transforms.Compose([
    transforms.Resize((img_height, img_width)),
    transforms.ToTensor()
])
# تابع برای پردازش تصویر
from torchvision import datasets


dataset_train = datasets.ImageFolder(root='/content/yolov5-fire-detection/datasets/fire/',transform=transform)
# بارگیری و پردازش تصاویر آموزشی
train_dl = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size, shuffle=True)
# بارگیری و پردازش تصاویر آموزشی

# بارگیری و پردازش تصاویر اعتبارسنجی

# بارگیری و پردازش تصاویر تست


# جایگزین کردن NUM_CLASSES با تعداد کلاس‌های دسته بندی
num_classes = 1

# ایجاد مدل EfficientNet
model = models.efficientnet_b0(pretrained=True)

# Add a global average pooling layer

# Replace the classifier with a new one


# جایگزین کردن NUM_EPOCHS با تعداد دوره‌های آموزش
num_epochs = 10

# تنظیمات آموزش
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

# آموزش مدل
for epoch in range(10):    # number of epochs
    print('Epoch {}/{}'.format(epoch, 10 - 1))
    print('-' * 10)
    
    # Each epoch has a training and validation phase
    for phase in ['train']:       
        
        if phase == 'train':      # train model
            model.train()  
        else:                    # evaluate model
            model.eval()  
            
        running_loss = 0.0        # loss for this epoch
        running_corrects = 0.0         # correct predictions
        
        # Iterate over data
        for images, labels in train_dl:
            
                 
         outputs = model(images)
         _, preds = torch.max(outputs, 1)     
         loss = criterion(outputs, labels)  
                
                
                      
         loss.backward()          
         optimizer.step()          
                    
                    
         running_loss += loss.item() * images.size(0)              
         running_corrects += torch.sum(preds == labels.data)
        
         epoch_loss = running_loss / len(train_dl)               
         epoch_acc = running_corrects.double() / len(train_dl)
        
         print('{} loss: {:.4f}, acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))       

print('Finished Training')
torch.save(model.state_dict(), '/content/model.pth')
torch.save(model.state_dict(), '/content/model.pt')

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch
import torchvision
import torchvision.models as models
from torchvision import transforms
import torch.nn as nn

from torchvision import datasets
input_shape = (3, 640,640)

batch_size = 64
img_height = 640
img_width = 640

transform =transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# تابع برای پردازش تصویر
from torchvision import datasets


dataset_train = datasets.ImageFolder(root='/content/yolov5-fire-detection/datasets/fire/',transform=transform)
# بارگیری و پردازش تصاویر آموزشی
train_dl = torch.utils.data.DataLoader(dataset_train, batch_size=batch_size, shuffle=True)

#models.efficientnet_b
# Load the EfficientNet model


# Freeze the weights of the EfficientNet model


# Create a new model with EfficientNet as the feature extractor


#Load the EfficientNet model
#model_efficientnet = EfficientNet.from_pretrained('efficientnet-b7')
#x = model.backbone.body.extract_features(inputs)

#Freeze the weights of the EfficientNet model

#Load the YOLOv5 model

#Set the model to evaluation mode

# %%
from efficientnet_pytorch import EfficientNet
model = EfficientNet.from_pretrained('efficientnet-b0')

num_epochs=1
#Define the dataloader and dataset for the training data
#+dataloader = torch.utils.data.DataLoader(dataset, batch_size=1)

#Loop over the training data


# Extract features from dataset
features = []
model.eval()
with torch.no_grad():
    for images, _ in train_dl:
        outputs = model.extract_features(images)
        features.append(outputs)

# Concatenate the extracted features into a single tensor
features = torch.cat(features, dim=0)

# Print the shape of the extracted features


 


print(features.shape)
# Out:
# torch.Size([3677, 1280, 7, 7])

# %%
import torch
from yolov5.models.yolo import Model

# Load YOLOv5 model 
model = Model(cfg='/content/yolov5s.yaml', ch=3, nc=80)

# Get feature map 


# Add feature map to YOLOv5 model
model.model[1].conv[0] = torch.nn.Conv2d(3677, 256, 1)  # adjust input channels
model.model[1][0].add(features)  # add feature map

# Example input 
with torch.no_grad():
    for images, _ in train_dl:
        output = model(images)
# Forward pass
# Out:
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  yolov5.models.common.Conv               [3, 32, 6, 2, 2]
#   1                -1  1     18560  yolov5.models.common.Conv               [32, 64, 3, 2]
#   2                -1  1     18816  yolov5.models.common.C3                 [64, 64, 1]
#   3                -1  1     73984  yolov5.models.common.Conv               [64, 128, 3, 2]
#   4                -1  2    115712  yolov5.models.common.C3                 [128, 128, 2]
#   5                -1  1    295424  yolov5.models.common.Conv               [128, 256, 3, 2]
#   6                -1  3    625152  yolov5.models.common.C3                 [256, 256, 3]
#   7                -1  1   1180672  yolov5.models.common.Conv               [256, 512, 3, 2]
#   8                -1  1   1182720  yolov5.models.common.C3                 [512, 512, 1]
# ...

# %%
import torch
from efficientnet_pytorch import EfficientNet
from yolov5.models.yolo import Model

# Load EfficientNet model
efficientnet = EfficientNet.from_pretrained('efficientnet-b0')

# Load YOLOv5 model 
model = Model(cfg='/content/yolov5s.yaml', ch=3, nc=80)

# Replace YOLOv5 backbone with EfficientNet
model.model[0] = efficientnet

# Example input 
with torch.no_grad():
    for images, _ in train_dl:
        output = model(images)
# Forward pass
# Out:
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  yolov5.models.common.Conv               [3, 32, 6, 2, 2]
#   1                -1  1     18560  yolov5.models.common.Conv               [32, 64, 3, 2]
#   2                -1  1     18816  yolov5.models.common.C3                 [64, 64, 1]
#   3                -1  1     73984  yolov5.models.common.Conv               [64, 128, 3, 2]
#   4                -1  2    115712  yolov5.models.common.C3                 [128, 128, 2]
#   5                -1  1    295424  yolov5.models.common.Conv               [128, 256, 3, 2]
#   6                -1  3    625152  yolov5.models.common.C3                 [256, 256, 3]
#   7                -1  1   1180672  yolov5.models.common.Conv               [256, 512, 3, 2]
#   8                -1  1   1182720  yolov5.models.common.C3                 [512, 512, 1]
# ...

# %%
from efficientnet_pytorch import EfficientNet

# Load pretrained EfficientNet model
effnet =EfficientNet(weights='imagenet')



# Compile YOLOv5 model (use default config)
from yolov5.models.yolo import Model

from yolov5.models.common import Conv


yolov5 = Model('/content/yolov5s.yaml')
# Get output of a middle layer of EfficientNet 

# Make YOLOv5 model take effnet output as input

# Freeze all layers of EfficientNet 

import tensorflow as tf

# Compile full model (freeze EfficientNet, train YOLOv5 part)
full_model = tf.keras.models.Model(inputs=effnet.input, outputs=yolov5.output)
full_model.compile(optimizer='adam', loss='mse')

# Train YOLOv5 part of model
full_model.fit(train_generator, 
                epochs=20, 
                )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-fb92dd081850> in <cell line: 4>()
#       2
#       3 # Load pretrained EfficientNet model
# ----> 4 effnet =EfficientNet(weights='imagenet')
#       5
#       6
#
# TypeError: EfficientNet.__init__() got an unexpected keyword argument 'weights'

# %%
import tensorflow as tf
from keras.utils import np_utils
from keras.callbacks import ReduceLROnPlateau, CSVLogger, EarlyStopping
import numpy as np
import os
from keras.callbacks import ModelCheckpoint
import scipy.io
from tensorflow.keras.layers import *
from keras.applications.densenet import DenseNet121
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dense
from tensorflow.keras.layers import AvgPool2D, GlobalAveragePooling2D, MaxPool2D
from tensorflow.keras.models import Model
from tensorflow.keras.layers import ReLU, concatenate
import tensorflow.keras.backend as K
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator
path_Tr     = '/content/yolov5-fire-detection/datasets/fire/train/images'                         	# Set PathTrain
#path_Te     = 'D:\\CVDataset\\Handwriting\\IAMDB\\Line5Ptch\\Te'                           	# Set Pathrest

batch_size = 16                                                                              #Set batch size


def read_data(path):
    select_files = 3000
    x_train = []
    y_train = []
    for (root, dirs, file) in os.walk(path):
        x_temp = []
        y_temp = []
        for f in file:
            file_path = os.path.join(root ,f)
            x_temp.append(file_path)
            y_temp.append(root.split('\\')[-1])
        x_train+=x_temp[:select_files]
        y_train+=y_temp[:select_files]

    df = pd.DataFrame(
        {'filename': x_train,
        'category': y_train})
    return df
train_df = read_data(path_Tr)
#test_df = read_dataTe(path_Te)

datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_dataframe(
    train_df,
    x_col= 'filename',
    y_col= 'category',
    target_size= (640,640),
    color_mode ="rgb",
    class_mode= 'categorical',
    batch_size= batch_size
)
# Out:
# Found 3000 validated image filenames belonging to 1 classes.

# %%
from torchvision import datasets, transforms, models
import torch
from yolov5.models.yolo import Model
yolo = Model(cfg='/content/yolov5s.yaml', ch=3)
from efficientnet_pytorch import EfficientNet
efficientnet = EfficientNet.from_pretrained('efficientnet-b7')

# Load the YOLOv5 model

# Load the EfficientNet model



# Loop over the training set
for i in range(0,5):
  for images, _ in train_dl:
    
    # Get a batch of images and labels
    
    
    # Pass the images through YOLOv5 first
    detections = yolo(images)
    
    # Extract feature maps from the last block of the efficient net
    feature_maps = efficientnet(images).feature_map[:, :, ::-1]
    
    # Concatenate the feature maps with the output of the last layer of the YOLOv5 network
    concat = torch.cat([detections[-1], feature_maps[-1]], dim=-1)

    # Free GPU memory
    torch.cuda.empty_cache()
# Out:
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  yolov5.models.common.Conv               [3, 32, 6, 2, 2]
#   1                -1  1     18560  yolov5.models.common.Conv               [32, 64, 3, 2]
#   2                -1  1     18816  yolov5.models.common.C3                 [64, 64, 1]
#   3                -1  1     73984  yolov5.models.common.Conv               [64, 128, 3, 2]
#   4                -1  2    115712  yolov5.models.common.C3                 [128, 128, 2]
#   5                -1  1    295424  yolov5.models.common.Conv               [128, 256, 3, 2]
#   6                -1  3    625152  yolov5.models.common.C3                 [256, 256, 3]
#   7                -1  1   1180672  yolov5.models.common.Conv               [256, 512, 3, 2]
#   8                -1  1   1182720  yolov5.models.common.C3                 [512, 512, 1]
# ...

# %%
import torch
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor, Resize, Compose

# Define the path to the dataset
data_path = '/content/yolov5-fire-detection/datasets/fire/'

# Define the data transforms
data_transforms = Compose([
    Resize((640, 640)),  # Resize the images to 224x224
    ToTensor()  # Convert the images to PyTorch tensors
])

# Load the dataset using the ImageFolder class
fire_dataset = ImageFolder(root=data_path, transform=data_transforms)

# Split the dataset into training and validation sets
train_size = int(0.8 * len(fire_dataset))
val_size = len(fire_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(fire_dataset, [train_size, val_size])

# Define the data loaders
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=True)

# %%
import torch.nn as nn
import torchvision.models as models

# Load the ResNet-18 model
resnet = models.resnet18(pretrained=False)

# Replace the last fully connected layer with a new one for classification
num_classes = 2
num_ftrs = resnet.fc.in_features
resnet.fc = nn.Linear(num_ftrs, num_classes)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
import torch.optim as optim
import torch.nn.functional as F

# Define the loss function
criterion = nn.CrossEntropyLoss()

# Define the optimizer
optimizer = optim.SGD(resnet.parameters(), lr=0.001, momentum=0.9)

# Define the number of training epochs
num_epochs = 10

# Train the model
for epoch in range(num_epochs):
    running_loss = 0.0
    for i, data in enumerate(train_dl, 0):
        images, labels = data
        optimizer.zero_grad()

        # Forward pass
        outputs = resnet(images)
        loss = criterion(outputs, labels)

        # Backward pass
        loss.backward()
        optimizer.step()

        # Print statistics
        running_loss += loss.item()
        if i % 10 == 9:
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 10))
            running_loss = 0.0

    # Evaluate the model after each epoch
    correct = 0
    total = 0
    with torch.no_grad():
        for data in train_dl:
            images, labels = data
            outputs = resnet(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print('Accuracy of the network on the train images: %d %%' % (
        100 * correct / total))
# Out:
# [1,    10] loss: 0.396
# [1,    20] loss: 0.264
# [1,    30] loss: 0.235
# [1,    40] loss: 0.154
